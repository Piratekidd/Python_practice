# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import random as rd

# %%
import datetime
import time

# %%
salaries_df = pd.read_csv(r"D:\Study\DS\Salaries.csv")

# %%
salaries_df['salary'].plot()
# Out:
# <Axes: >

# %%
salaries_df.plot(kind = 'scatter',x='service',y='salary')
# Out:
# <Axes: xlabel='service', ylabel='salary'>

# %%
.corr('service','salary')
# Out:
#   Cell In[11], line 1
#     .corr('service','salary')
#     ^
# SyntaxError: invalid syntax

# %%
salaries_df['salary'].corr(salaries_df['service'])
# Out:
# 0.5321913486037866

# %%
salaries_df['salary'].corr(salaries_df['phd'])
# Out:
# 0.5813556072724514

# %%
salaries_df["salary"].plot(kind = 'hist',bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
salaries_df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
salaries_df["service"].plot(kind = 'hist',bins = 10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
rank_totals = salaries_df.groupby("sex")[["service","phd"]].mean().sort_values(by='service',ascending = False)

print(rank_totals)
rank_totals.plot(kind='barh')
plt.title('title',loc='left')
# Out:
#           service        phd
# sex
# Male    18.538462  22.897436
# Female  11.564103  16.512821
# Text(0.0, 1.0, 'title')

# %%
rank_totals = salaries_df.groupby("sex")[["service","phd"]].mean().sort_values(by='service',ascending = False)

print(rank_totals)
rank_totals.plot(kind='bar',stacked = True)
# Out:
#           service        phd
# sex
# Male    18.538462  22.897436
# Female  11.564103  16.512821
# <Axes: xlabel='sex'>

# %%
salaries_df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
phd_totals = round(salaries_df.groupby("rank")["phd"].mean(),2).sort_values(ascending = False)
print(phd_totals)
phd_totals.plot(kind='barh')
# Out:
# rank
# Prof         27.07
# AssocProf    15.08
# AsstProf      5.05
# Name: phd, dtype: float64
# <Axes: ylabel='rank'>

# %%
salaries_df.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
rank_totals.plot(kind='pie',subplots = True)
# Out:
# array([<Axes: ylabel='service'>, <Axes: ylabel='phd'>], dtype=object)

# %%
rank_totals.plot.bar(color = ['red','green'],subplots = True,rot=90)
# Out:
# array([<Axes: title={'center': 'service'}, xlabel='sex'>,
#        <Axes: title={'center': 'phd'}, xlabel='sex'>], dtype=object)

# %%
salaries_df['salary'].plot.box()
# Out:
# <Axes: >

# %%
salaries_df['salary'].plot(kind='box')
# Out:
# <Axes: >

# %%
salaries_df['phd'].plot(kind='box')
# Out:
# <Axes: >

# %%
salaries_df[['phd','service']].plot.box(vert=False)
# Out:
# <Axes: >

# %%
salaries_df['phd'].plot.box()
# Out:
# <Axes: >

# %%
salaries_df[['service','phd']].plot.area(alpha=0.5)
# Out:
# <Axes: >

# %%
salaries_df[['service','phd']].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
salaries_df.count()
# Out:
# rank          78
# discipline    78
# phd           78
# service       78
# sex           78
# salary        78
# dtype: int64

# %%
pd.plotting.bootstrap_plot(salaries_df['salary'])

# %%
plt.plot(salaries_df['salary'])

# %%
plt.bar(salaries_df['salary'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 plt.bar(salaries_df['salary'])
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
plt.hist(salaries_df['salary'],bins=10,histtype='bar',color='green');

# %%
plt.collections()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 plt.collections()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'collections'

# %%
plt.figure
# Out:
# <function matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, *, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)>

# %%
plt.scatter(x=salaries_df['salary'],y=salaries_df['phd'],edgecolor='yellow',marker="^")

# %%
plt.subplot

# %%
plt.scatter3d

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x="total_bill",y="tip",hue="sex",size="smoker",marker="*",data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
diamond = sns.load_dataset("diamonds")

# %%
diamond
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
fmri = sns.load_dataset("fmri")
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x="timepoint",y="signal",hue="region",data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(x="class",y="fare",hue="sex",data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
iris = sns.load_dataset("iris")

# %%
iris.count()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.histplot(x="petal_length",data=iris,bins=6,kde=True)
sns.histplot(x="petal_width",data=iris,bins=6,kde=True)

sns.histplot(x="sepal_length",data=iris,bins=6,kde=True)
sns.histplot(x="sepal_width",data=iris,bins=6,kde=True);

# %%
sns.kdeplot(x="petal_length",data=iris)
sns.kdeplot(x="petal_width",data=iris)

sns.kdeplot(x="sepal_length",data=iris)
sns.kdeplot(x="sepal_width",data=iris);

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.kdeplot(x="total_bill",hue="time",data=tips);

# %%
i_corr = iris.corr()
# Out:
# C:\Users\Shubh\AppData\Local\Temp\ipykernel_8408\1764133899.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   i_corr = iris.corr()

# %%
sns.pairplot(data=iris);

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Load iris dataset
iris = sns.load_dataset("iris")
# Create pair plot with custom settings
sns.pairplot(data=iris, hue="species", diag_kind="kde", palette="husl")
# Set title
plt.title("Iris Dataset Pair Plot")
# Show plot
plt.show()

# %%
emp = pd.read_csv("D:\Study\DS\employees.csv")

# %%
emp.count()
# Out:
# First Name            933
# Gender                855
# Start Date           1000
# Last Login Time      1000
# Salary               1000
# Bonus %              1000
# Senior Management     933
# Team                  957
# dtype: int64

# %%
emp["Gender"].fillna("No Gender",inplace = True)
mode = emp["Senior Management"].mode().values[0]
emp["Senior Management"]= emp["Senior Management"].replace(np.nan,mode)
emp.isnull().sum()
# Out:
# First Name           67
# Gender                0
# Start Date            0
# Last Login Time       0
# Salary                0
# Bonus %               0
# Senior Management     0
# Team                 43
# dtype: int64

# %%
emp
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male  08-06-1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...
