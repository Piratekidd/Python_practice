# %%
import pandas as pd

# %%
lst = ['f','2','k',2,'000']
s1 = pd.Series(lst)

# %%
s1
# Out:
# 0      f
# 1      2
# 2      k
# 3      2
# 4    000
# dtype: object

# %%
s1[2]
# Out:
# 'k'

# %%
s1.size
# Out:
# 5

# %%
s1.head(2)
# Out:
# 0    f
# 1    2
# dtype: object

# %%
s1.tail(2)
# Out:
# 3      2
# 4    000
# dtype: object

# %%
s1.values.itemsize
# Out:
# 8

# %%
import pandas as pd

# %%
df=pd.DataFrame({"temp_c":[37,38]},index=["Malaysia","Maldives"])
df
# Out:
#           temp_c
# Malaysia      37
# Maldives      38

# %%
df.assign(temp_f=df["temp_c"]*(9/5)+32)
# Out:
#           temp_c  temp_f
# Malaysia      37    98.6
# Maldives      38   100.4

# %%
import numpy as np

# %%
n1=np.array([1,2,3,4,5,6])

# %%
print(type(n1))
# Out:
# <class 'numpy.ndarray'>

# %%
sample_df = pd.read_csv(r"D:\Study\Python\Sample_dataset.csv")

# %%
sample_df
# Out:
#    Sr. no. First Name  Last Name  Age Qualification
# 0        1       Joe    Williams   25            MCA
# 1        2     Oliver      Trump   24         B.TECH
# 2        3      Sagar      Dubey   25            BCA
# 3        4       Liaa    Edwards   26            MBA
# 4        5      Mansi  Deshpande   22             CA
# 5        6      Rocky      Lewis   21            BCA
# 6        7      Harry     Harris   23          B.COM
# 7        8       Tina     Bailey   28             BA
# 8        9       Ansh    Shriwas   29         M.TECH
# 9       10    Michael      Davis   29            MBA

# %%
sample_df.describe()
# Out:
#         Sr. no.        Age
# count  10.00000  10.000000
# mean    5.50000  25.200000
# std     3.02765   2.820559
# min     1.00000  21.000000
# 25%     3.25000  23.250000
# 50%     5.50000  25.000000
# 75%     7.75000  27.500000
# max    10.00000  29.000000

# %%
import pandas as pd

# %%
data_df = pd.read_csv(r"D:\Study\Python\data.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data_df = pd.read_csv(r"D:\Study\Python\data.csv")
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([0,6])
ypoints = np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
data_df = pd.read_csv(r"C:\Users\Shubh\Downloads\tips.csv")

# %%
data_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(data_df["day"],data_df["tip"],data_df["total_bill"],data_df["size"])
plt.title("Tips Data")
plt.xlabel("day")
plt.ylabel("tips")
plt.colorbar()
plt.show()

# %%
plt.plot(data_df["tip"])
plt.plot(data_df["total_bill"])

# %%
plt.bar(data_df["day"],data_df["tip"])
# Out:
# <BarContainer object of 244 artists>

# %%
x=np.array(["a","b","c","d"])
y=np.array([15,25,4,56])
plt.barh(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
x=np.array(["a","b","c","d"])
plt.hist(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 2
#       1 x=np.array(["a","b","c","d"])
# ----> 2 plt.hist(x,y)
#
# File C:\ProgramData\anaconda3\lib\site-packages\matplotlib\pyplot.py:2618, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2612 @_copy_docstring_and_deprecators(Axes.hist)
#    2613 def hist(
#    2614         x, bins=None, range=None, density=False, weights=None,
#    2615         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2616         orientation='vertical', rwidth=None, log=False, color=None,
#    2617         label=None, stacked=False, *, data=None, **kwargs):
# -> 2618     return gca().hist(
#    2619         x, bins=bins, range=range, density=density, weights=weights,
# ...

# %%
plt.hist(data_df["total_bill"])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
data_d = sns.load_dataset("tips")

# %%
sns.lineplot(x="tip",y="total_bill",data=data_d)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.countplot(x="smoker",data=data_d)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.pairplot(data=data_d,hue="tip")

# %%
sns.scatterplot(data=data_d,x="tip",y="total_bill")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.histplot(data=data_d,x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
AAAAAAAAA
