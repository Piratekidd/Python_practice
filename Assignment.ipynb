# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
sample_data = pd.read_csv(r"D:\Study\Practice files\Sample_data.csv")

# %%
sample_data.isnull().sum()
# Out:
# Student ID      0
# school          0
# Gender          0
# April_MT        0
# May_MT          0
# June_MT         0
# July_MT         0
# August_MT       0
# September_MT    0
# dtype: int64

# %% [markdown]
# # Trend Analysis over month

# %%
sample_data
# Out:
#     Student ID school Gender  April_MT  May_MT  June_MT  July_MT  August_MT  \
# 0        A0001      A   Girl         5       6        6        0         11
# 1        A0002      A   Girl         5       5        6        9         11
# 2        A0003      A   Girl         7       8       10       12         13
# 3        A0004      A   Girl        15      14       15       14         14
# 4        A0005      A   Girl         6      10       10       11         13
# ..         ...    ...    ...       ...     ...      ...      ...        ...
# 392    J000393      J    Boy        10       8        7       12         13
# 393    J000394      J    Boy        11      12       10       14         14
# 394    J000395      J    Boy         8       9        9       14         14
# 395    J000396      J   Girl         5       6        6       12         12
# 396    J000397      J    Boy         6       5        0       16         16
#
#      September_MT
# 0              11
# ...

# %%
april_avg = sample_data['April_MT'].mean()
may_avg = sample_data['May_MT'].mean()
june_avg = sample_data['June_MT'].mean()
july_avg = sample_data['July_MT'].mean()
aug_avg = sample_data['August_MT'].mean()
sept_avg = sample_data['September_MT'].mean()

# %%
july_avg/june_avg
# Out:
# 1.1577669902912622

# %%
months = ['April', 'May', 'June', 'July', 'August', 'September']
math_scores = [april_avg, may_avg, june_avg, july_avg, aug_avg, sept_avg]

plt.figure(figsize=(8, 6))
plt.plot(months, math_scores, marker='o', color='b', label='Math Scores')

plt.title('Monthly Math Test Scores')
plt.xlabel('Months')
plt.ylabel('Scores')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Gender bsed Analysis

# %%
sample_data['Gender'].value_counts()
# Out:
# Girl    209
# Boy     188
# Name: Gender, dtype: int64

# %%
april_avg_boy = sample_data[sample_data['Gender']=='Boy']['April_MT'].mean()
may_avg_boy = sample_data[sample_data['Gender']=='Boy']['May_MT'].mean()
june_avg_boy = sample_data[sample_data['Gender']=='Boy']['June_MT'].mean()
july_avg_boy = sample_data[sample_data['Gender']=='Boy']['July_MT'].mean()
aug_avg_boy = sample_data[sample_data['Gender']=='Boy']['August_MT'].mean()
sept_avg_boy = sample_data[sample_data['Gender']=='Boy']['September_MT'].mean()

# %%
april_avg_girl = sample_data[sample_data['Gender']=='Girl']['April_MT'].mean()
may_avg_girl = sample_data[sample_data['Gender']=='Girl']['May_MT'].mean()
june_avg_girl = sample_data[sample_data['Gender']=='Girl']['June_MT'].mean()
july_avg_girl = sample_data[sample_data['Gender']=='Girl']['July_MT'].mean()
aug_avg_girl = sample_data[sample_data['Gender']=='Girl']['August_MT'].mean()
sept_avg_girl = sample_data[sample_data['Gender']=='Girl']['September_MT'].mean()

# %%
months = ['April', 'May', 'June', 'July', 'August', 'September']

Boy = [april_avg_boy,may_avg_boy,june_avg_boy,july_avg_boy,aug_avg_boy,sept_avg_boy]
Girl = [april_avg_girl,may_avg_girl,june_avg_girl,july_avg_girl,aug_avg_girl,sept_avg_girl]

plt.figure(figsize=(8, 6))
plt.plot(months, Boy, marker='o', color='b', label='Boy Scores')
plt.plot(months, Girl, marker='o', color='g', label='Girl Scores')


plt.title('Monthly Math Test Scores')
plt.xlabel('Months')
plt.ylabel('Scores')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# # School-wise Analysis

# %%
sample_data['school'].value_counts()
# Out:
# E    64
# C    62
# H    56
# I    39
# D    38
# B    35
# A    34
# G    31
# F    28
# J    10
# Name: school, dtype: int64

# %%
april_avg_A = sample_data[sample_data['school']=='A']['April_MT'].mean()
may_avg_A = sample_data[sample_data['school']=='A']['May_MT'].mean()
june_avg_A = sample_data[sample_data['school']=='A']['June_MT'].mean()
july_avg_A = sample_data[sample_data['school']=='A']['July_MT'].mean()
aug_avg_A = sample_data[sample_data['school']=='A']['August_MT'].mean()
sept_avg_A = sample_data[sample_data['school']=='A']['September_MT'].mean()

# %%
april_avg_B = sample_data[sample_data['school']=='B']['April_MT'].mean()
may_avg_B = sample_data[sample_data['school']=='B']['May_MT'].mean()
june_avg_B = sample_data[sample_data['school']=='B']['June_MT'].mean()
july_avg_B = sample_data[sample_data['school']=='B']['July_MT'].mean()
aug_avg_B = sample_data[sample_data['school']=='B']['August_MT'].mean()
sept_avg_B = sample_data[sample_data['school']=='B']['September_MT'].mean()

# %%
april_avg_C = sample_data[sample_data['school']=='C']['April_MT'].mean()
may_avg_C = sample_data[sample_data['school']=='C']['May_MT'].mean()
june_avg_C = sample_data[sample_data['school']=='C']['June_MT'].mean()
july_avg_C = sample_data[sample_data['school']=='C']['July_MT'].mean()
aug_avg_C = sample_data[sample_data['school']=='C']['August_MT'].mean()
sept_avg_C = sample_data[sample_data['school']=='C']['September_MT'].mean()

# %%
april_avg_D = sample_data[sample_data['school']=='D']['April_MT'].mean()
may_avg_D = sample_data[sample_data['school']=='D']['May_MT'].mean()
june_avg_D = sample_data[sample_data['school']=='D']['June_MT'].mean()
july_avg_D = sample_data[sample_data['school']=='D']['July_MT'].mean()
aug_avg_D = sample_data[sample_data['school']=='D']['August_MT'].mean()
sept_avg_D = sample_data[sample_data['school']=='D']['September_MT'].mean()

# %%
april_avg_E = sample_data[sample_data['school']=='E']['April_MT'].mean()
may_avg_E = sample_data[sample_data['school']=='E']['May_MT'].mean()
june_avg_E = sample_data[sample_data['school']=='E']['June_MT'].mean()
july_avg_E = sample_data[sample_data['school']=='E']['July_MT'].mean()
aug_avg_E = sample_data[sample_data['school']=='E']['August_MT'].mean()
sept_avg_E = sample_data[sample_data['school']=='E']['September_MT'].mean()

# %%
april_avg_F = sample_data[sample_data['school']=='F']['April_MT'].mean()
may_avg_F = sample_data[sample_data['school']=='F']['May_MT'].mean()
june_avg_F = sample_data[sample_data['school']=='F']['June_MT'].mean()
july_avg_F = sample_data[sample_data['school']=='F']['July_MT'].mean()
aug_avg_F = sample_data[sample_data['school']=='F']['August_MT'].mean()
sept_avg_F = sample_data[sample_data['school']=='F']['September_MT'].mean()

# %%
april_avg_G = sample_data[sample_data['school']=='G']['April_MT'].mean()
may_avg_G = sample_data[sample_data['school']=='G']['May_MT'].mean()
june_avg_G = sample_data[sample_data['school']=='G']['June_MT'].mean()
july_avg_G = sample_data[sample_data['school']=='G']['July_MT'].mean()
aug_avg_G = sample_data[sample_data['school']=='G']['August_MT'].mean()
sept_avg_G = sample_data[sample_data['school']=='G']['September_MT'].mean()

# %%
april_avg_H = sample_data[sample_data['school']=='H']['April_MT'].mean()
may_avg_H = sample_data[sample_data['school']=='H']['May_MT'].mean()
june_avg_H = sample_data[sample_data['school']=='H']['June_MT'].mean()
july_avg_H = sample_data[sample_data['school']=='H']['July_MT'].mean()
aug_avg_H = sample_data[sample_data['school']=='H']['August_MT'].mean()
sept_avg_H = sample_data[sample_data['school']=='H']['September_MT'].mean()

# %%
april_avg_I = sample_data[sample_data['school']=='I']['April_MT'].mean()
may_avg_I = sample_data[sample_data['school']=='I']['May_MT'].mean()
june_avg_I = sample_data[sample_data['school']=='I']['June_MT'].mean()
july_avg_I = sample_data[sample_data['school']=='I']['July_MT'].mean()
aug_avg_I = sample_data[sample_data['school']=='I']['August_MT'].mean()
sept_avg_I = sample_data[sample_data['school']=='I']['September_MT'].mean()

# %%
april_avg_J = sample_data[sample_data['school']=='J']['April_MT'].mean()
may_avg_J = sample_data[sample_data['school']=='J']['May_MT'].mean()
june_avg_J = sample_data[sample_data['school']=='J']['June_MT'].mean()
july_avg_J = sample_data[sample_data['school']=='J']['July_MT'].mean()
aug_avg_J = sample_data[sample_data['school']=='J']['August_MT'].mean()
sept_avg_J = sample_data[sample_data['school']=='J']['September_MT'].mean()

# %%
months = ['April', 'May', 'June', 'July', 'August', 'September']

School_A = [april_avg_A,may_avg_A,june_avg_A,july_avg_A,aug_avg_A,sept_avg_A]
School_B = [april_avg_B,may_avg_B,june_avg_B,july_avg_B,aug_avg_B,sept_avg_B]
School_C = [april_avg_C,may_avg_C,june_avg_C,july_avg_C,aug_avg_C,sept_avg_C]
School_D = [april_avg_D,may_avg_D,june_avg_D,july_avg_D,aug_avg_D,sept_avg_D]
School_E = [april_avg_E,may_avg_E,june_avg_E,july_avg_E,aug_avg_E,sept_avg_E]
School_F = [april_avg_F,may_avg_F,june_avg_F,july_avg_F,aug_avg_F,sept_avg_F]
School_G = [april_avg_G,may_avg_G,june_avg_G,july_avg_G,aug_avg_G,sept_avg_G]
School_H = [april_avg_H,may_avg_H,june_avg_H,july_avg_H,aug_avg_H,sept_avg_H]
School_I = [april_avg_I,may_avg_I,june_avg_I,july_avg_I,aug_avg_I,sept_avg_I]
School_J = [april_avg_J,may_avg_J,june_avg_J,july_avg_J,aug_avg_J,sept_avg_J]




plt.figure(figsize=(8, 6))
plt.plot(months, School_A, marker='o', color='b', label='School_A')
plt.plot(months, School_B, marker='o', color='g', label='School_B')
plt.plot(months, School_C, marker='o', color='r', label='School_C')
plt.plot(months, School_D, marker='o', color='c', label='School_D')
plt.plot(months, School_E, marker='o', color='m', label='School_E')
plt.plot(months, School_F, marker='o', color='y', label='School_F')
plt.plot(months, School_G, marker='^', color='b', label='School_G')
plt.plot(months, School_H, marker='^', color='g', label='School_H')
plt.plot(months, School_I, marker='^', color='r', label='School_I')
plt.plot(months, School_J, marker='^', color='c', label='School_J')


plt.title('Monthly Math Test Scores')
plt.xlabel('Months')
plt.ylabel('Scores')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Model

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import numpy as np
from sklearn.linear_model import LinearRegression

# Assuming 'months' and 'math_scores' are lists or 1D arrays
months = np.array(months).reshape(-1, 1)  # Convert to 2D array
math_scores = np.array(math_scores)  # Ensure math_scores is a 1D array

# One-hot encode the month names
encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')
months_encoded = encoder.fit_transform(np.array(months).reshape(-1, 1))

# Create and fit the model
model = LinearRegression()
model.fit(months_encoded, math_scores)

# Encode future months
future_months = ['October', 'November']  # Example future months
future_months_encoded = encoder.transform(np.array(future_months).reshape(-1, 1))

# Predict scores for future months
predicted_scores = model.predict(future_months_encoded)
print(predicted_scores)
# Out:
# [12.41321599 12.41321599]
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
